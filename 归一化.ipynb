# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
norm = pd.read_csv('./traindata20200920v44.csv',header=0)
norm = norm.iloc[:,1:]
norm
# Out:
#       AET1901  AET1902  AET1903  AET1904  AET1905  AET1906  AET1907  AET1908  \
# 0           0        0        0      241      463      901      937      795
# 1           0        0        0      384      371      824      729      721
# 2           0        0        0      619      490      909      805      729
# 3           0        0        0      619      490      909      805      729
# 4           0        0        0      619      490      909      805      729
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1984        0        0        0        0      103      838      964      945
# 1985        0        0        0      139      859      919     1021      970
# 1986        0        0        0       68      851      965     1010      989
# 1987        0        0        0        0      759      900      978      981
# 1988        0        0        0      201      874      984     1009      979
#
# ...

# %%
norma = preprocessing.normalize(norm, axis=0, norm='max')
norma
np.savetxt("testresult20200020norm3.csv", norma,delimiter=",")
