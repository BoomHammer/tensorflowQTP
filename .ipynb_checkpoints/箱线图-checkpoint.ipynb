# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams["font.sans-serif"]=["SimHei"] #设置字体
plt.rcParams["axes.unicode_minus"]=False #该语句解决图像中的“-”负号的乱码问题

# %%
data_train=pd.read_csv('F:/TensorFlow/traindata20230508.csv',header=0,encoding='utf_8')
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17211 entries, 0 to 17210
# Columns: 257 entries, ClassName to Wgs84Y
# dtypes: float64(26), int64(230), object(1)
# memory usage: 33.7+ MB

# %%
data_Kp = data_train[data_train['ClassName'] == '高山嵩草（Kobresia pygmaea）草甸']['DEM']
data_Sp = data_train[data_train['ClassName'] == '紫花针茅（Stipa purpurea）草原']['DEM']
data_En = data_train[data_train['ClassName'] == '垂穗披碱草（Elymus nutans）高寒草甸']['DEM']
data_Kh = data_train[data_train['ClassName'] == '矮生嵩草（Kobresia humilis）草甸']['DEM']
data_Sb = data_train[data_train['ClassName'] == '长芒草（Stipa bungeana）草原']['DEM']

# %%
plt.figure(figsize=(10,5))#设置画布的尺寸
plt.title('植被图中海拔与文献差异较大的类型\n的训练数据的高程分布',fontsize=14)#标题，并设定字号大小
labels = '高山嵩草草甸','紫花针茅草原', '垂穗披碱草高寒草甸', '矮生嵩草草甸', '长芒草草原'#图例

#vert=False:水平箱线图；showmeans=True：显示均值
plt.boxplot([data_Kp, data_Sp, data_En, data_Kh, data_Sb], labels = labels, vert=False,)
plt.show()#显示图像
