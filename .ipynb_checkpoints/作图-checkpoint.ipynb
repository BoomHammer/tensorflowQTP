# %%
#-- coding: utf-8 --
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('./guancong.csv',header=0)
df = df.iloc[:,1:]
df = df.describe()
df
# Out:
#          AET1901    AET1902    AET1903    AET1904    AET1905    AET1906  \
# count  36.000000  36.000000  36.000000  36.000000  36.000000  36.000000
# mean    0.046639   0.039278   0.058611   0.103117   0.512889   0.624833
# std     0.198763   0.171691   0.197957   0.174261   0.188610   0.220897
# min     0.000000   0.000000   0.000000   0.000000   0.117000   0.122000
# 25%     0.000000   0.000000   0.000000   0.000000   0.420750   0.532000
# 50%     0.000000   0.000000   0.000000   0.030100   0.560000   0.687000
# 75%     0.000000   0.000000   0.000000   0.166500   0.692000   0.758000
# max     1.000000   1.000000   1.000000   0.738000   0.756000   1.000000
#
#          AET1907    AET1908    AET1909    AET1910  ...  SR190829B5  \
# count  36.000000  36.000000  36.000000  36.000000  ...   36.000000
# mean    0.741583   0.666778   0.701139   0.318478  ...    0.415500
# std     0.102697   0.169402   0.166911   0.259428  ...    0.122235
# ...

# %%
p25 = df.loc[['25%'],:]
p25
# Out:
#      AET1901  AET1902  AET1903  AET1904  AET1905  AET1906  AET1907  AET1908  \
# 25%      0.0      0.0      0.0      0.0  0.42075    0.532     0.74    0.531
#
#      AET1909  AET1910  ...  SR190829B5  SR190829B6  SR190829B7  SR190930B1  \
# 25%    0.565  0.11345  ...       0.364       0.347      0.2485         0.1
#
#      SR190930B2  SR190930B3  SR190930B4  SR190930B5  SR190930B6  SR190930B7
# 25%     0.20575    0.054575    0.088125     0.37725     0.35475       0.251
#
# [1 rows x 253 columns]

# %%
df.iloc[5]
# Out:
# AET1901       0.0000
# AET1902       0.0000
# AET1903       0.0000
# AET1904       0.0301
# AET1905       0.5600
#                ...
# SR190930B3    0.1225
# SR190930B4    0.1465
# SR190930B5    0.4625
# SR190930B6    0.4340
# SR190930B7    0.3405
# Name: 50%, Length: 253, dtype: float64

# %%
df.iloc[6].plot(kind='area',stacked=False,color='lightblue',alpha=1)
df.iloc[4].plot(kind='area',stacked=False,color='white',alpha=1)
df.iloc[1].plot(color='royalblue')
plt.title('Shrub', y=-0.2) 
#plt.title('$\it{Kobresia}$ $\it{humilis}$ Meadow', y=-0.2)
plt.show()
