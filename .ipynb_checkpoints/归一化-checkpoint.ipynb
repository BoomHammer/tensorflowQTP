# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
norm = pd.read_csv('./traindata20200920v33.csv',header=0,encoding='gb2312')
norm = norm.iloc[:,1:]
norm

# %%
norma = preprocessing.normalize(norm, axis=1)
norma
#np.savetxt("testresult20200020norm.csv", norma, fmt="%d",delimiter=",")
