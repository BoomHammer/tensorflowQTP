# %%
#-- coding: utf-8 --
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('./changmangcaoyuan1.csv',header=0)
df = df.iloc[:,1:]
df = df.describe()
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-d616b2a95bf5> in <module>
# ----> 1 df = pd.read_csv('./changmangcaoyuan1.csv',header=0)
#       2 df = df.iloc[:,1:]
#       3 df = df.describe()
#       4 df
#
# ...

# %%
df.iloc[6].plot(kind='area',stacked=False,color='lightblue',alpha=1)
df.iloc[4].plot(kind='area',stacked=False,color='white',alpha=1)
df.iloc[1].plot(color='royalblue')
plt.title('$\it{Stipa}$ $\it{bungeana}$, $\it{Leymus}$ $\it{secalinus}$ and $\it{Artemisia}$ $\it{scoparia}$ Steppe', y=-0.2)
plt.show()
